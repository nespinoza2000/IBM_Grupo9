# %% [markdown]
# Importar librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Leer conjunto de datos:

# %%
df_clientes = pd.read_csv("./Base/Clientes.csv", sep=';')
df_productos = pd.read_csv("./Base/Productos.csv", sep=';')
df_ventas = pd.read_csv("./Base/Ventas.csv", sep=';')
df_detalle_ventas = pd.read_csv("./Base/Detalle_ventas.csv", sep=';')
